# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.models import Word2Vec

# %%
df = pd.read_csv('../data/processed/preprocessed_text.csv')
df = df.dropna()

# %%
poems = df['cleaned_text'].tolist()
model = Word2Vec(poems, vector_size=100, window=5, min_count=1, sg=1)

# %%
import numpy as np
poem_vectors = []
for poem in poems:
    poem_vector = np.mean([model.wv[word] for word in poem if word in model.wv], axis=0)
    poem_vectors.append(poem_vector)


poem_vectors = np.array(poem_vectors)

# %%
poem_vectors = np.nan_to_num(poem_vectors)

# %%
wcss = []
for i in range(2, 11):  
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(poem_vectors)
    wcss.append(kmeans.inertia_)


plt.figure(figsize=(10, 6))
plt.plot(range(2, 11), wcss, marker='o')
plt.title('Elbow Method for Optimal Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
silhouette_scores = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    cluster_labels = kmeans.fit_predict(encoded_poem_vectors)
    silhouette_avg = silhouette_score(encoded_poem_vectors, cluster_labels)
    silhouette_scores.append(silhouette_avg)

# Plotting the Silhouette Method results
plt.figure(figsize=(10, 6))
plt.plot(range(2, 11), silhouette_scores, marker='o')
plt.title('Silhouette Scores for Optimal Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input


input_dim = poem_vectors.shape[1]
input_layer = Input(shape=(input_dim,))
encoded = Dense(64, activation='relu')(input_layer)
encoded = Dense(32, activation='relu')(encoded)
decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mse')


autoencoder.fit(poem_vectors, poem_vectors, epochs=100, batch_size=8, shuffle=True)


encoder = Model(input_layer, encoded)
encoded_poem_vectors = encoder.predict(poem_vectors)
# Out:
# WARNING:tensorflow:From C:\Users\Acer\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Acer\anaconda3\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Acer\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Acer\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 5/5 [==============================] - 2s 9ms/step - loss: 0.2470
# Epoch 2/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2396
# Epoch 3/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2284
# Epoch 4/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2108
# Epoch 5/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1842
# Epoch 6/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1477
# Epoch 7/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1043
# Epoch 8/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0632
# Epoch 9/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0338
# Epoch 10/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0182
# Epoch 11/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0118
# Epoch 12/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0094
# Epoch 13/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0084
# Epoch 14/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 15/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 16/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0071
# Epoch 17/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 18/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 19/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0063
# Epoch 20/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0061
# Epoch 21/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0059
# Epoch 22/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0058
# Epoch 23/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0056
# Epoch 24/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0055
# Epoch 25/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0055
# Epoch 26/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0054
# Epoch 27/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0053
# Epoch 28/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0053
# Epoch 29/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0052
# Epoch 30/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0052
# Epoch 31/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0051
# Epoch 32/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0051
# Epoch 33/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0051
# Epoch 34/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0050
# Epoch 35/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0050
# Epoch 36/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0050
# Epoch 37/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0050
# Epoch 38/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0050
# Epoch 39/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0049
# Epoch 40/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0049
# Epoch 41/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0049
# Epoch 42/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0049
# Epoch 43/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0049
# Epoch 44/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0049
# Epoch 45/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0049
# Epoch 46/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0048
# Epoch 47/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 48/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0048
# Epoch 49/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0048
# Epoch 50/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 51/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 52/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0048
# Epoch 53/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 54/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0048
# Epoch 55/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 56/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0047
# Epoch 57/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0047
# Epoch 58/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0047
# Epoch 59/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0047
# Epoch 60/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0047
# Epoch 61/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 62/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 63/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 64/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 65/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 66/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 67/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 68/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 69/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 70/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 71/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 72/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 73/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 74/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 75/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 76/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 77/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 78/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 79/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 80/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 81/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 82/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 83/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 84/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 85/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0045
# Epoch 86/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 87/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 88/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 89/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 90/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0045
# Epoch 91/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 92/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 93/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 94/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 95/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 96/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 97/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 98/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 99/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 100/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0045
# 2/2 [==============================] - 0s 7ms/step

# %%
from sklearn.cluster import KMeans


kmeans = KMeans(n_clusters=5, random_state=42)
clusters = kmeans.fit_predict(encoded_poem_vectors)


df['cluster'] = clusters


df.to_csv('clustered_poems.csv', index=False)
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
df
# cluster_mapping = {
#     0: "Nature",
#     1: "Society",
#     2: "Rural Life & Culture",
#     3: "Spirituality"
# }

# df['category'] = df['cluster'].map(cluster_mapping)

# %%
df
# Out:
#                 Title                                       cleaned_text  \
# 0              भिखारी  beggar stand still pitiful eye look silent lig...
# 1                बादल  offspring vast water born summer heat festive ...
# 2    तिनको घँसिया गीत  velvetsoft grassy green roof mountain lush bea...
# 3             सन्ध्या  lalitpurs highart craftsmanship wonder chisel ...
# 4              सम्झना  cloud gather sky sadness descends upon life ta...
# 5              यात्री  temple traveler temple seek offering carry pla...
# 6         प्रश्नोत्तर  nectar drink god earn honest everyone seek hap...
# 7            आफ्नो घर  thought enter sharp fill heart light dark nigh...
# 9               वृक्ष  tree stand tall spread wide dense cool leaf wh...
# 10               गरीब  poor rich happiness wont wealth anywhere world...
# 11              वसन्त  season arrived earthqueen moonmad bee hum bird...
# 12               जीवन  awakening cry tender sweet dawn enchantment ba...
# 13           अन्त्यमा  twinkling star twinkling star distant light ho...
# 14     जिन्दगीको मौसम  may season life remain plowing field heart lay...
# 15               झरना  mountain peak saw water cascading wondrous dra...
# 16              घाँसी  handsome youth slept soundly pillow stone bene...
# 17        सुनको बिहान  golden day dawn land open way colorful cloud s...
# 18          पाप लाग्छ  pluck bud sin incurs dare thud tear flower chi...
# 19               पैसा  oh money bright valuable eye light world round...
# 20        सिँह र मुसा  hot summer day sun scorching hot sky ablaze he...
# 21              वर्षा  oh ghar ghar ghar ghar jhar jhar jhar jhil li ...
# 22           मास्टरजी  small chin beard beginning sprout black stubbl...
# 23              पल्टन  drum war thunder arm clear beloved nation marc...
# 24    सौन्दर्य-उपासना  yearn thing beautiful fill heart mind grace ey...
# 25            फूल-परी  garden full colorful playful fairy oh beautifu...
# 26          किताब-चरो  beautiful bookbird poor thing spread two wing ...
# 27               धूलो  dust homeland water mingle pouring heavy rain ...
# 28  नेपाली सलाई बट्टा  shimmering ray adorn radiant face intensely re...
# 29          कुहू कुहू  forest make cuckoo sound oh remains unknown fl...
# 30             तस्वीर  little one ready delightful beautiful fun may ...
# 31   हैँसा बुढीको मुख  face devoid joy laughter covered wrinkle count...
# 32      गाउँ दिने कथा  riding howdah horse elephant atop howdah playf...
# 33     पृथ्वी-भकुण्डो  round earth wobbly pumpkin spinning day day ki...
# 34               जुनी  life stealing troubling like fly life decorati...
# 35             झाँगघर  let build home together though world earth hea...
#
#     cluster              category
# 0         2  Rural Life & Culture
# 1         1               Society
# 2         1               Society
# 3         1               Society
# 4         1               Society
# 5         2  Rural Life & Culture
# 6         3          Spirituality
# 7         2  Rural Life & Culture
# 9         2  Rural Life & Culture
# 10        1               Society
# 11        1               Society
# 12        1               Society
# 13        2  Rural Life & Culture
# 14        1               Society
# 15        2  Rural Life & Culture
# 16        2  Rural Life & Culture
# 17        2  Rural Life & Culture
# 18        2  Rural Life & Culture
# 19        1               Society
# 20        1               Society
# 21        4                   NaN
# 22        0                Nature
# 23        2  Rural Life & Culture
# 24        2  Rural Life & Culture
# 25        1               Society
# 26        3          Spirituality
# 27        1               Society
# 28        2  Rural Life & Culture
# 29        1               Society
# 30        2  Rural Life & Culture
# 31        2  Rural Life & Culture
# 32        5                   NaN
# 33        0                Nature
# 34        0                Nature
# 35        0                Nature

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)
reduced_vectors = pca.fit_transform(encoded_poem_vectors)

plt.scatter(reduced_vectors[:, 0], reduced_vectors[:, 1], c=clusters)
plt.colorbar()
plt.show()
